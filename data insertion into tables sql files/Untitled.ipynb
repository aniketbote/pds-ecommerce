# %%
import pandas as pd
import numpy as np

# %%
sellers = pd.read_csv("../final_data/sellers.csv")
sellers
# Out:
#        seller_id              name                         email  \
# 0    CBAYSELLER1       Cecily Wall         cecily.wall@yahoo.com
# 1    CBAYSELLER2      Eden Coleman        eden.coleman@yahoo.com
# 2    CBAYSELLER3   Zach Washington   zach.washington@outlook.com
# 3    CBAYSELLER4   Kristina Holmes     kristina.holmes@gmail.com
# 4    CBAYSELLER5     Wilson Hayden       wilson.hayden@yahoo.com
# 5    CBAYSELLER6       Shaun Frost         shaun.frost@yahoo.com
# 6    CBAYSELLER7    Karim Matthams    karim.matthams@outlook.com
# 7    CBAYSELLER8       Jenna Mejia       jenna.mejia@outlook.com
# 8    CBAYSELLER9      Jonty Conner        jonty.conner@yahoo.com
# 9   CBAYSELLER10      Abdur Benton        abdur.benton@gmail.com
# 10  CBAYSELLER11      Carla Tucker      carla.tucker@outlook.com
# 11  CBAYSELLER12    Katrina Campos      katrina.campos@gmail.com
# 12  CBAYSELLER13  Hermione Mcclain    hermione.mcclain@yahoo.com
# ...

# %%
for i in range(20):
    print("INSERT INTO Sellers (seller_id, name, email, address, phone_num) values (", 
          "'", sellers.iloc[i]["seller_id"], "',",
          "'", sellers.iloc[i]["name"], "',", 
          "'", sellers.iloc[i]["email"], "',",
          "'", sellers.iloc[i]["address"], "',",
          sellers.iloc[i]["phone_num"], ");")
# Out:
# INSERT INTO Sellers (seller_id, name, email, address, phone_num) values ( ' CBAYSELLER1 ', ' Cecily Wall ', ' cecily.wall@yahoo.com ', ' 611 Valley St. Massillon, OH 44646 ', 2579628381 );
# INSERT INTO Sellers (seller_id, name, email, address, phone_num) values ( ' CBAYSELLER2 ', ' Eden Coleman ', ' eden.coleman@yahoo.com ', ' 254 Lookout Street Bear, DE 19701 ', 6585341215 );
# INSERT INTO Sellers (seller_id, name, email, address, phone_num) values ( ' CBAYSELLER3 ', ' Zach Washington ', ' zach.washington@outlook.com ', ' 8720 Newport Street Crystal Lake, IL 60014 ', 7776347309 );
# INSERT INTO Sellers (seller_id, name, email, address, phone_num) values ( ' CBAYSELLER4 ', ' Kristina Holmes ', ' kristina.holmes@gmail.com ', ' 64 Van Dyke Circle Titusville, FL 32780 ', 2819497046 );
# ...

# %%
coupons = pd.read_csv("../final_data/coupons.csv")
coupons
# Out:
#    coupon_id         name  discount  start_date    end_date
# 0     MTUOGB       FLAT20      0.20  2020-01-01  2030-01-01
# 1     UAWYVQ  BLACKFRIDAY      0.50  2021-11-26  2021-11-26
# 2     GHXANS   FIRSTORDER      0.50  2020-01-01  2030-01-01
# 3     KPFVWY   SUMMERSALE      0.30  2021-05-01  2021-09-01
# 4     YZKSWQ   WINTERSALE      0.30  2021-09-01  2022-03-01
# 5     KZFGFA       KZFGFA      0.11  2022-05-19  2023-04-21
# 6     MAILAP       MAILAP      0.20  2022-03-06  2023-08-05
# 7     GTFWGT       GTFWGT      0.15  2022-06-29  2023-10-01
# 8     KGSXXU       KGSXXU      0.05  2022-07-20  2023-06-14
# 9     LITZMO       LITZMO      0.10  2022-03-24  2023-09-12
# 10    NHTBVT       NHTBVT      0.18  2022-07-16  2023-12-05
# 11    LMFWGF       LMFWGF      0.20  2022-06-28  2023-11-16
# 12    WAFANK       WAFANK      0.08  2022-06-13  2023-01-21
# 13    NOAXDQ       NOAXDQ      0.11  2022-03-13  2023-09-22
# 14    WXKVAA       WXKVAA      0.18  2022-03-25  2023-11-13
# ...

# %%
for i in range(30):
    print("INSERT INTO coupons (coupon_id , name , discount , start_date , end_date) values (", 
          "'", coupons.iloc[i]["coupon_id"], "',",
          "'", coupons.iloc[i]["name"], "',", 
          coupons.iloc[i]["discount"], ",",
          "'", coupons.iloc[i]["start_date"], "',",
          "'", coupons.iloc[i]["end_date"], "');")
# Out:
# INSERT INTO coupons (coupon_id , name , discount , start_date , end_date) values ( ' MTUOGB ', ' FLAT20 ', 0.2 , ' 2020-01-01 ', ' 2030-01-01 ');
# INSERT INTO coupons (coupon_id , name , discount , start_date , end_date) values ( ' UAWYVQ ', ' BLACKFRIDAY ', 0.5 , ' 2021-11-26 ', ' 2021-11-26 ');
# INSERT INTO coupons (coupon_id , name , discount , start_date , end_date) values ( ' GHXANS ', ' FIRSTORDER ', 0.5 , ' 2020-01-01 ', ' 2030-01-01 ');
# INSERT INTO coupons (coupon_id , name , discount , start_date , end_date) values ( ' KPFVWY ', ' SUMMERSALE ', 0.3 , ' 2021-05-01 ', ' 2021-09-01 ');
# INSERT INTO coupons (coupon_id , name , discount , start_date , end_date) values ( ' YZKSWQ ', ' WINTERSALE ', 0.3 , ' 2021-09-01 ', ' 2022-03-01 ');
# INSERT INTO coupons (coupon_id , name , discount , start_date , end_date) values ( ' KZFGFA ', ' KZFGFA ', 0.11 , ' 2022-05-19 ', ' 2023-04-21 ');
# ...

# %%
employees = pd.read_csv('../final_data/employees.csv')
employees
# Out:
#       employee_id        employee_name designation   department
# 0    CBAYEMP00001        Nicola Oliver      Worker    receiving
# 1    CBAYEMP00002           Jason Rees      Worker    receiving
# 2    CBAYEMP00003        Natalie Jones      Worker    receiving
# 3    CBAYEMP00004          Harry Avery      Worker    receiving
# 4    CBAYEMP00005         Adrian Paige      Worker      putaway
# 5    CBAYEMP00006         Cameron King      Worker      putaway
# 6    CBAYEMP00007          Joe Forsyth      Worker      putaway
# 7    CBAYEMP00008     Penelope Ellison      Worker      putaway
# 8    CBAYEMP00009        Sarah Edmunds      Worker      storage
# 9   CBAYEMP000010         Jane Jackson      Worker      storage
# 10  CBAYEMP000011        Mary Mitchell      Worker      storage
# 11  CBAYEMP000012    Alexandra Langdon      Worker      storage
# 12  CBAYEMP000013        Diane Edmunds      Worker      picking
# 13  CBAYEMP000014          Peter Welch      Worker      picking
# ...

# %%
for i in range(30):
    print("INSERT INTO employees (employee_id, employee_name, designation, department) values (", 
          "'", employees.iloc[i]["employee_id"], "',",
          "'", employees.iloc[i]["employee_name"], "',",
          "'", employees.iloc[i]["designation"], "',",
          "'", employees.iloc[i]["department"], "');")
# Out:
# INSERT INTO employees (employee_id, employee_name, designation, department) values ( ' CBAYEMP00001 ', ' Nicola Oliver ', ' Worker ', ' receiving ');
# INSERT INTO employees (employee_id, employee_name, designation, department) values ( ' CBAYEMP00002 ', ' Jason Rees ', ' Worker ', ' receiving ');
# INSERT INTO employees (employee_id, employee_name, designation, department) values ( ' CBAYEMP00003 ', ' Natalie Jones ', ' Worker ', ' receiving ');
# INSERT INTO employees (employee_id, employee_name, designation, department) values ( ' CBAYEMP00004 ', ' Harry Avery ', ' Worker ', ' receiving ');
# INSERT INTO employees (employee_id, employee_name, designation, department) values ( ' CBAYEMP00005 ', ' Adrian Paige ', ' Worker ', ' putaway ');
# INSERT INTO employees (employee_id, employee_name, designation, department) values ( ' CBAYEMP00006 ', ' Cameron King ', ' Worker ', ' putaway ');
# ...

# %%
products = pd.read_csv("../products.csv")
products
# Out:
#       product_id                           name   price  availability
# 0    CBAYPDT0001                 C-bay Mattress  149.99          1000
# 1    CBAYPDT0002                  C-bay Pillows   14.99          1000
# 2    CBAYPDT0003            C-bay Cloth Hangars    5.99          1000
# 3    CBAYPDT0004                C-bay Bed Frame   74.99          1000
# 4    CBAYPDT0005                C-bay Bed Sheet   13.99          1000
# 5    CBAYPDT0006                C-bay Comforter   24.99          1000
# 6    CBAYPDT0007             C-bay Wine Glasses   27.99          1000
# 7    CBAYPDT0008                C-bay Plate Set   34.99          1000
# 8    CBAYPDT0009    C-bay Storage Container Set   19.99          1000
# 9   CBAYPDT00010                C-bay Knife Set   16.99          1000
# 10  CBAYPDT00011                C-bay Spoon Set    9.99          1000
# 11  CBAYPDT00012        C-bay Cast Iron Skillet   13.99          1000
# ...

# %%
for i in range(30):
    print("INSERT INTO products (product_id, name , price ,availability) values (", 
          "'", products.iloc[i]["product_id"], "',",
          "'", products.iloc[i]["name"], "',", 
          products.iloc[i]["price"], ",",
          products.iloc[i]["availability"],");")
# Out:
# INSERT INTO products (product_id, name , price ,availability) values ( ' CBAYPDT0001 ', ' C-bay Mattress ', 149.99 , 1000 );
# INSERT INTO products (product_id, name , price ,availability) values ( ' CBAYPDT0002 ', ' C-bay Pillows ', 14.99 , 1000 );
# INSERT INTO products (product_id, name , price ,availability) values ( ' CBAYPDT0003 ', ' C-bay Cloth Hangars ', 5.99 , 1000 );
# INSERT INTO products (product_id, name , price ,availability) values ( ' CBAYPDT0004 ', ' C-bay Bed Frame ', 74.99 , 1000 );
# INSERT INTO products (product_id, name , price ,availability) values ( ' CBAYPDT0005 ', ' C-bay Bed Sheet ', 13.99 , 1000 );
# INSERT INTO products (product_id, name , price ,availability) values ( ' CBAYPDT0006 ', ' C-bay Comforter ', 24.99 , 1000 );
# INSERT INTO products (product_id, name , price ,availability) values ( ' CBAYPDT0007 ', ' C-bay Wine Glasses ', 27.99 , 1000 );
# ...

# %%
import random
'''
Create table MadeReview(
    customer_id  varchar(16),
    product_id varchar(16),
    stars integer not null,
    review text,
    primary key(customer_id, product_id),
    foreign key(Customer_id ) references Customers(customer_id),
    foreign key(product_id) references Products(product_id)
);
'''

pdt_dict = {}
product_ids = list(products["product_id"])
customer_ids = list(customers['customer_id'])
for pdt in product_ids:
    pdt_dict[pdt] = {}
    count = random.randint(0, 4)
    i = 0
    while i<count:
        cust = random.choice(customer_ids)
        if cust not in pdt_dict[pdt].keys():
            i+=1
            pdt_dict[pdt][cust] = random.randint(1, 5)
print(pdt_dict)
# Out:
# {'CBAYPDT0001': {710936: 2, 250478: 3}, 'CBAYPDT0002': {807336: 3, 770430: 1}, 'CBAYPDT0003': {462488: 4, 488269: 1, 887561: 1}, 'CBAYPDT0004': {525285: 2, 532186: 1, 372023: 1}, 'CBAYPDT0005': {836535: 1, 372023: 5, 696323: 1}, 'CBAYPDT0006': {}, 'CBAYPDT0007': {724131: 1}, 'CBAYPDT0008': {804227: 2, 685032: 5}, 'CBAYPDT0009': {}, 'CBAYPDT00010': {}, 'CBAYPDT00011': {495114: 4}, 'CBAYPDT00012': {294197: 5}, 'CBAYPDT00013': {731585: 3, 507465: 3, 579944: 4, 185266: 2}, 'CBAYPDT00014': {132192: 3, 585180: 3, 610746: 2, 715915: 2}, 'CBAYPDT00015': {807336: 2, 342623: 2}, 'CBAYPDT00016': {155199: 3, 800914: 5, 710936: 3}, 'CBAYPDT00017': {223825: 2, 811096: 1, 894432: 4, 710936: 1}, 'CBAYPDT00018': {297857: 2, 579944: 1, 984747: 3}, 'CBAYPDT00019': {989381: 3, 570959: 3, 126064: 1}, 'CBAYPDT00020': {804227: 4, 155199: 5, 989381: 4, 280203: 2}, 'CBAYPDT00021': {645067: 1}, 'CBAYPDT00022': {663494: 5, 968675: 3, 223825: 2, 579944: 1}, 'CBAYPDT00023': {884910: 2, 297857: 1}, 'CBAYPDT00024'
# ...

# %%
review_cust_ids = []
review_pdt_ids = []
stars = []
reviews = []
primary_key = []
foreign_key = 

'CBAYPDT0001': {542778: 4, 710936: 5, 663494: 5, 113972: 2}
