# %%
import pandas as pd
import numpy as np

# %%
madereviews = pd.read_csv('madereview.csv')
madereviews
# Out:
#     customer_id   product_id  stars  \
# 0        542778  CBAYPDT0001      4
# 1        807336  CBAYPDT0002      2
# 2        770430  CBAYPDT0002      1
# 3        525285  CBAYPDT0004      2
# 4        532186  CBAYPDT0004      1
# 5        372023  CBAYPDT0004      1
# 6        836535  CBAYPDT0005      3
# 7        372023  CBAYPDT0005      3
# 8        696323  CBAYPDT0005      4
# 9        724131  CBAYPDT0007      3
# 10       804227  CBAYPDT0008      4
# 11       685032  CBAYPDT0008      5
# 12       495114  CBAYPDT0011      4
# 13       294197  CBAYPDT0012      5
# 14       731585  CBAYPDT0013      3
# 15       507465  CBAYPDT0013      3
# 16       579944  CBAYPDT0013      4
# 17       610746  CBAYPDT0014      2
# 18       715915  CBAYPDT0014      2
# 19       807336  CBAYPDT0015      5
# 20       342623  CBAYPDT0015      5
# 21       223825  CBAYPDT0019      5
# 22       811096  CBAYPDT0019      4
# 23       894432  CBAYPDT0019      4
# 24       710936  CBAYPDT0019      3
# ...

# %%
madereviews.dtypes
# Out:
# customer_id     int64
# product_id     object
# stars           int64
# review         object
# dtype: object

# %%
customer_ids = list(madereviews['customer_id'])
customer_ids = [str(cur_id) for cur_id in customer_ids]
madereviews['customer_id'] = pd.Series(customer_ids)
madereviews
# Out:
#    customer_id   product_id  stars  \
# 0       542778  CBAYPDT0001      4
# 1       807336  CBAYPDT0002      2
# 2       770430  CBAYPDT0002      1
# 3       525285  CBAYPDT0004      2
# 4       532186  CBAYPDT0004      1
# 5       372023  CBAYPDT0004      1
# 6       836535  CBAYPDT0005      3
# 7       372023  CBAYPDT0005      3
# 8       696323  CBAYPDT0005      4
# 9       724131  CBAYPDT0007      3
# 10      804227  CBAYPDT0008      4
# 11      685032  CBAYPDT0008      5
# 12      495114  CBAYPDT0011      4
# 13      294197  CBAYPDT0012      5
# 14      731585  CBAYPDT0013      3
# 15      507465  CBAYPDT0013      3
# 16      579944  CBAYPDT0013      4
# 17      610746  CBAYPDT0014      2
# 18      715915  CBAYPDT0014      2
# 19      807336  CBAYPDT0015      5
# 20      342623  CBAYPDT0015      5
# 21      223825  CBAYPDT0019      5
# 22      811096  CBAYPDT0019      4
# 23      894432  CBAYPDT0019      4
# 24      710936  CBAYPDT0019      3
# ...

# %%
madereviews.dtypes
# Out:
# customer_id    object
# product_id     object
# stars           int64
# review         object
# dtype: object
